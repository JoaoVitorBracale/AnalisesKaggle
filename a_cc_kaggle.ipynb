# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#Importing the dataset
ds_cc = pd.read_csv('UCI_Credit_Card.csv')

# %%
#Apresentation the dataset
ds_cc.head(10)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
# 5   6    50000.0    1          1         2   37      0      0      0      0
# 6   7   500000.0    1          1         2   29      0      0      0      0
# 7   8   100000.0    2          2         2   23      0     -1     -1      0
# 8   9   140000.0    2          3         1   28      0      0      2      0
# 9  10    20000.0    1          3         2   35     -2     -2     -2     -2
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# ...

# %%
#Checking the dataset fields and data type
ds_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null float64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null float64
# BILL_AMT2                     30000 non-null float64
# BILL_AMT3                     30000 non-null float64
# BILL_AMT4                     30000 non-null float64
# ...

# %%
ds_cc.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %% [markdown]
# Creation of categorization functions for better interpretation / understanding of the dataset

# %%
#Based on the description and additional information passed from the available dataset

def d_sex(sex):
    if sex == 1:
        return 'Male'
    elif sex == 2:
        return 'Female'

def d_education(edu):
    if edu == 1:
        return 'Graduate school'
    elif edu == 2:
        return 'University'
    elif edu == 3:
        return 'High schoo'
    elif edu == 4:
        return 'Other'
    elif edu == 5 or edu == 6:
        return 'Unknown'
    
def d_marriage(marriage):
    if marriage == 1:
        return 'Married'
    elif marriage == 2:
        return 'Single'
    elif marriage == 3:
        return 'Other'
    
def d_payment(pay):
    if pay == 0:
        return 'No'
    elif pay == 1:
        return 'Yes'
    
def pays(p):
    if p == -1:
        return 'Pay duly'
    elif p == 0:
        return 'Unknown'
    elif p == 1:
        return 'Payment delay for one month'
    elif p == 2:
        return 'Payment delay for two month'
    elif p == 3:
        return 'Payment delay for three month'
    elif p == 4:
        return 'Payment delay for four month'
    elif p == 5:
        return 'Payment delay for five month'
    elif p == 6:
        return 'Payment delay for six month'
    elif p == 7:
        return 'Payment delay for seven month'
    elif p == 8:
        return 'Payment delay for eight month'
    elif p == 9:
        return 'Payment delay for nine month and above'

# %%
#Applying functions to their respective columns
        
ds_cc['SEX'] = ds_cc['SEX'].apply(d_sex)

ds_cc['EDUCATION'] = ds_cc['EDUCATION'].apply(d_education)

ds_cc['MARRIAGE'] = ds_cc['MARRIAGE'].apply(d_marriage)

ds_cc['default.payment.next.month'] = ds_cc['default.payment.next.month'].apply(d_payment)

ds_cc['PAY_0'] = ds_cc['PAY_0'].apply(pays)
ds_cc['PAY_2'] = ds_cc['PAY_2'].apply(pays)
ds_cc['PAY_3'] = ds_cc['PAY_3'].apply(pays)
ds_cc['PAY_4'] = ds_cc['PAY_4'].apply(pays)
ds_cc['PAY_5'] = ds_cc['PAY_5'].apply(pays)
ds_cc['PAY_6'] = ds_cc['PAY_6'].apply(pays)

# %%
#Dataset after modifications
ds_cc.head(10)
# Out:
#    ID  LIMIT_BAL     SEX        EDUCATION MARRIAGE  AGE  \
# 0   1    20000.0  Female       University  Married   24
# 1   2   120000.0  Female       University   Single   26
# 2   3    90000.0  Female       University   Single   34
# 3   4    50000.0  Female       University  Married   37
# 4   5    50000.0    Male       University  Married   57
# 5   6    50000.0    Male  Graduate school   Single   37
# 6   7   500000.0    Male  Graduate school   Single   29
# 7   8   100000.0  Female       University   Single   23
# 8   9   140000.0  Female       High schoo  Married   28
# 9  10    20000.0    Male       High schoo   Single   35
#
#                          PAY_0                        PAY_2  \
# 0  Payment delay for two month  Payment delay for two month
# 1                     Pay duly  Payment delay for two month
# 2                      Unknown                      Unknown
# 3                      Unknown                      Unknown
# ...

# %%
ds_cc.groupby('SEX')['PAY_0'].value_counts()
# Out:
# SEX     PAY_0
# Female  Unknown                          8706
#         Pay duly                         3554
#         Payment delay for one month      2196
#         Payment delay for two month      1547
#         Payment delay for three month     163
#         Payment delay for four month       32
#         Payment delay for eight month       9
#         Payment delay for five month        8
#         Payment delay for six month         5
#         Payment delay for seven month       4
# Male    Unknown                          6031
#         Pay duly                         2132
#         Payment delay for one month      1492
#         Payment delay for two month      1120
#         Payment delay for three month     159
#         Payment delay for four month       44
#         Payment delay for five month       18
#         Payment delay for eight month      10
#         Payment delay for six month         6
#         Payment delay for seven month       5
# ...

# %% [markdown]
# First, the proportion of men and women in the dataset

# %%
sns.countplot(ds_cc['SEX'])

# %% [markdown]
# It is also important to know their schooling level

# %%
fs = (13, 5)
fig, ax = pyplot.subplots(figsize=fs)
sns.countplot(ds_cc['EDUCATION'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7a669d4a39d6> in <module>
#       1 fs = (13, 5)
# ----> 2 fig, ax = pyplot.subplots(figsize=fs)
#       3 sns.countplot(ds_cc['EDUCATION'])
#
# NameError: name 'pyplot' is not defined

# %% [markdown]
# In a simple and clear way, a visualization of the credit limits granted to all customers

# %%
sns.distplot(ds_cc['LIMIT_BAL'])

# %% [markdown]
# September 2005 payments

# %%
title = 'Title'
ds_cc.groupby('PAY_0')['PAY_0'].value_counts().plot(kind = 'barh', title = title, figsize=(12,6))

# %% [markdown]
# August 2005 payments

# %%
title = 'Title'
ds_cc.groupby('PAY_2')['PAY_2'].value_counts().plot(kind = 'barh', title = title, figsize=(12,6))

# %%
sns.pairplot(ds_cc, kind = 'reg')
plt.show()
